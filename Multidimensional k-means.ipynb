# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("Second Data Analysis - Sheet1 (2).csv")
df=df.drop(df.index[61])
df=df.drop(df.index[60])
df=df.drop(df.index[59])
df=df.drop(df.index[58])
df=df.drop(["Counties"],axis=1)
df.tail()
# Out:
#    Population Increase in Unemployment Rate (Jan to April) % of county White  \
# 53     465861                                          8.3              30.1
# 54      54539                                         12.4              81.2
# 55     850967                                           10              46.6
# 56     220408                                          6.7              48.1
# 57      78041                                          9.1                57
#
#     % of county Black  % of county Asian  % of county Hispanic
# 53               1.59                3.5                  62.3
# 54               1.90                1.3                  11.4
# 55               1.76                7.1                  41.6
# 56               2.46               13.9                  30.8
# 57               3.06                6.9                  26.8

# %%
df2=pd.read_csv("Total Minority California Dataset - Sheet1.csv")
df2=df2.drop(["Population"],axis=1)
df2=df2.drop(["Counties"],axis=1)
df2.head()
X=df2.values

# %%
total=0
for i in range(58):
    total+=float(df.iloc[i,2])
avg=total/58
print("White average: ",avg)

total=0
for i in range(58):
    total+=float(df.iloc[i,3])
avg=total/58
print("Black average: ",avg)

total=0
for i in range(58):
    total+=float(df.iloc[i,4])
avg=total/58
print("Asian average: ",avg)

total=0
for i in range(58):
    total+=float(df.iloc[i,5])
avg=total/58
print("Hispanic average: ",avg)

total=0
for i in range(58):
    if (float(df.iloc[i,2])>55.25):
        total+=1
print(total)

total=0
for i in range(58):
    if (float(df.iloc[i,3])>3.12):
        total+=1
print(total)

total=0
for i in range(58):
    if (float(df.iloc[i,4])>7.09):
        total+=1
print(total)
# Out:
# White average:  55.25172413793103
# Black average:  3.1215517241379316
# Asian average:  7.094827586206896
# Hispanic average:  29.47413793103448
# 28
# 16
# 17

# %%
0.17*0.08
# Out:
# 0.013600000000000001

# %%
df_withoutpop=df.drop(["Population"],axis=1)
df_withoutpop.shape
df_withoutpop.values
# Out:
# array([['10.9', '32.6', 11.3, 28.2, 22.0],
#        ['17', '67.9', 0.8, 0.8, 7.8],
#        ['9.7', '79.6', 2.4, 1.5, 12.9],
#        ['9.9', '73.4', 1.5, 4.3, 15.3],
#        ['9', '82.3', 0.6, 1.0, 11.2],
#        ['7.8', '36.9', 1.0, 1.6, 57.8],
#        ['11.3', '45.6', 8.8, 15.5, 24.6],
#        ['6.8', '63.1', 2.3, 2.4, 19.2],
#        ['11.6', '78.7', 1.0, 4.2, 12.4],
#        ['8.8', '30.8', 5.0, 9.9, 51.6],
#        ['8.7', '53.1', 0.7, 2.4, 40.2],
#        ['9.7', '75.4', 1.2, 2.8, 10.5],
#        ['10.1', '11.9', 2.7, 1.4, 82.1],
#        ['9.9', '64', 1.0, 1.2, 21.1],
#        ['10.1', '36', 5.5, 4.6, 51.1],
#        ['7.6', '33.6', 6.39, 3.8, 52.5],
#        ['10.7', '72.3', 2.18, 1.4, 18.7],
#        ['6', '66.1', 8.91, 1.7, 18.3],
#        ['16.3', '26.7', 8.27, 14.2, 47.9],
#        ['8.6', '35.8', 3.33, 2.0, 55.9],
#        ['8.8', '71.9', 2.34, 5.7, 15.6],
#        ['11.9', '81.5', 1.28, 1.3, 10.1],
#        ['13.9', '66.4', 0.65, 1.8, 23.9],
# ...

# %%
#from sklearn.datasets.samples_generator import make_blobs
#X, y_true = make_blobs(n_samples=300, centers=4,
#                       cluster_std=0.60, random_state=0)
W=[]
B=[]
A=[]
U=[]
for i in range(58):
    W.append([float(df.iloc[i,2]),float(df.iloc[i,1])])
    B.append([float(df.iloc[i,3]),float(df.iloc[i,1])])
    A.append([float(df.iloc[i,4]),float(df.iloc[i,1])])
    U.append(float(df.iloc[i,1]))
W=np.array(X)
B=np.array(B)
A=np.array(A)
scaler = StandardScaler()
scaled_data = scaler.fit_transform(X)
scaled_data2 = scaler.fit_transform(B)
scaled_data3 = scaler.fit_transform(A)
#plt.scatter(scaled_data[:, 0], scaled_data[:, 1], s=50);
#plt.scatter(scaled_data2[:, 0], scaled_data2[:, 1], s=50);
#plt.scatter(scaled_data3[:, 0], scaled_data3[:, 1], s=50);

plt.scatter(W[:, 0], W[:, 1], s=50);
plt.scatter(B[:, 0], B[:, 1], s=50);
plt.scatter(A[:, 0], A[:, 1], s=50);
#plt.scatter(X)

# %%
plt.scatter(X[:, 0], X[:, 1], s=50);
plt.scatter(B[:, 0], B[:, 1], s=50);
plt.scatter(A[:, 0], A[:, 1], s=50);
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3)


kmeans.fit(df)
y_kmeans = kmeans.predict(df)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=500,alpha=0.5);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-f990168dbc65> in <module>()
# ----> 1 plt.scatter(X[:, 0], X[:, 1], s=50);
#       2 plt.scatter(B[:, 0], B[:, 1], s=50);
#       3 plt.scatter(A[:, 0], A[:, 1], s=50);
#       4 from sklearn.cluster import KMeans
#       5 kmeans = KMeans(n_clusters=3)
#
# NameError: name 'X' is not defined

# %%
kmeans.fit(X)
y_kmeans = kmeans.predict(X)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

kmeans = KMeans(n_clusters=3)
kmeans.fit(B)
y_kmeans = kmeans.predict(B)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='blue', s=200, alpha=0.5);

kmeans = KMeans(n_clusters=3)
kmeans.fit(A)
y_kmeans = kmeans.predict(A)
centers = kmeans.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='green', s=200, alpha=0.5);

# %%
print(__doc__)


# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn import datasets

np.random.seed(5)

iris = datasets.load_iris()
X = iris.data
y = iris.target

print(y)
X=[[30.1,1.59,3.5,8.3],[81.2,1.90,1.3,12.4],[46.6,1.76,7.1,10],[48.1,2.46,13.9,6.7]]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="darkgrid")
iris = sns.load_dataset("iris")

# Subset the iris dataset by species
setosa = iris.query("species == 'setosa'")
virginica = iris.query("species == 'virginica'")

# Set up the figure first
f, ax = plt.subplots(figsize=(20, 12))
ax.set_aspect("equal")

scaled_data = scaler.fit_transform(W)
scaled_data2 = scaler.fit_transform(B)
scaled_data3 = scaler.fit_transform(A)

# Draw the two density plots

ax = sns.kdeplot(df["% of county Black"],df["Increase in Unemployment Rate (Jan to April)"],
                 cmap="Reds", shade=False, shade_lowest=False)
ax = sns.kdeplot(df["% of county White"],df["Increase in Unemployment Rate (Jan to April)"],
                 cmap="Blues", shade=False, shade_lowest=False)
ax = sns.kdeplot(df["% of county Asian"],df["Increase in Unemployment Rate (Jan to April)"],
                 cmap="Greens", shade=False, shade_lowest=False)
#ax = sns.kdeplot(df["% of county Hispanic"],df["Increase in Unemployment Rate (Jan to April)"],
#                 cmap="Greens", shade=True, shade_lowest=False)







#ax.figsize(12,8)
# Add labels to the plot
red = sns.color_palette("Reds")[-2]
blue = sns.color_palette("Blues")[-2]
ax.text(17.5, 8.2, "White", size=16, color=blue)
ax.text(3.8, 4.5, "Black", size=16, color=red)





"""
f, ax2 = plt.subplots(figsize=(20, 12))
ax2.set_aspect("equal")

# Draw the two density plots
ax2 = sns.kdeplot(A, U,
                 cmap="Greens", shade=True, shade_lowest=False)
ax2 = sns.kdeplot(W, U,
                 cmap="Blues", shade=True, shade_lowest=False)

red = sns.color_palette("Reds")[-2]
blue = sns.color_palette("Blues")[-2]
ax2.text(17.5, 8.2, "White", size=16, color=blue)
ax2.text(3.8, 4.5, "Asian", size=16, color=red)
"""
# Out:
# '\nf, ax2 = plt.subplots(figsize=(20, 12))\nax2.set_aspect("equal")\n\n# Draw the two density plots\nax2 = sns.kdeplot(A, U,\n                 cmap="Greens", shade=True, shade_lowest=False)\nax2 = sns.kdeplot(W, U,\n                 cmap="Blues", shade=True, shade_lowest=False)\n\nred = sns.color_palette("Reds")[-2]\nblue = sns.color_palette("Blues")[-2]\nax2.text(17.5, 8.2, "White", size=16, color=blue)\nax2.text(3.8, 4.5, "Asian", size=16, color=red)\n'

# %%
sns.set(style="darkgrid")
iris = sns.load_dataset("iris")

# Subset the iris dataset by species
setosa = iris.query("species == 'setosa'")
virginica = iris.query("species == 'virginica'")

# Set up the figure first
f, ax = plt.subplots(figsize=(20, 12))
ax.set_aspect("equal")

scaled_data = scaler.fit_transform(W)
scaled_data2 = scaler.fit_transform(B)
scaled_data3 = scaler.fit_transform(A)

# Draw the two density plots

ax = sns.kdeplot([11.3,8.8,8.91,8.27,9.9,8.58,6.98,14.3,    3.5,5.2,4.6,3.52],[10.9,11.3,6,16.3,10.6,9.7,11.1,11.1,    5.3,8.5,7.1,8.3],
                 cmap="Reds", shade=True, shade_lowest=False)
ax = sns.kdeplot([67.9,79.6,73.4,82.3,63.1,78.7,53.1,75.4,64,72.3,71.9,81.5,66.4,77.6,65.9,53.7,85.6,74.3,83.7,
                  69.7,45.9,58.2,81,85.9,77.6,64.4,44.1,48,69.8,83,81.2,46.6,48.1,57,
                 
                 
                 62.4,50.9,47.1,57.8,77.6,80.7,31.4
                 ],[17,9.7,9.9,9,6.8,11.6,8.7,9.7,9.9,10.7,8.8,11.9,
                  13.9, 4.2, 24.8, 12.6,11.5,9.7,10.3,10.9,9.2,10.9,10.2,8.4,7.4,11.6,10.9,9.5,8.1,5.8,12.4,10,6.7,9.1,
                   
                   
                
                 5.9,2.7,1.6,2.6,13.4,9.6,10],
                 cmap="Blues", shade=True, shade_lowest=False)
#ax = sns.kdeplot(df["% of county Hispanic"],df["Increase in Unemployment Rate (Jan to April)"],
#                 cmap="Greens", shade=True, shade_lowest=False)

# %%
sns.set(style="darkgrid")
iris = sns.load_dataset("iris")

# Subset the iris dataset by species
setosa = iris.query("species == 'setosa'")
virginica = iris.query("species == 'virginica'")

# Set up the figure first
f, ax = plt.subplots(figsize=(20, 12))
ax.set_aspect("equal")

scaled_data = scaler.fit_transform(W)
scaled_data2 = scaler.fit_transform(B)
scaled_data3 = scaler.fit_transform(A)

# Draw the two density plots

ax = sns.kdeplot([11.3,8.8,8.91,8.27,9.9,8.58,6.98,14.3,    3.5,5.2,4.6,3.52,
                 
                 11.04],[10.9,11.3,6,16.3,10.6,9.7,11.1,11.1,    5.3,8.5,7.1,8.3,     30.1],
                 cmap="Reds", shade=True, shade_lowest=False)
ax = sns.kdeplot([67.9,79.6,73.4,82.3,63.1,78.7,53.1,75.4,64,72.3,71.9,81.5,66.4,77.6,65.9,53.7,85.6,74.3,83.7,
                  69.7,45.9,58.2,81,85.9,77.6,64.4,44.1,48,69.8,83,81.2,46.6,48.1,57,
                 
                 
                 62.4,50.9,47.1,57.8,77.6,80.7,31.4,
                  
                  
                  
                  
                 74.5,81.5,67.5,84.8,98.3,65.5,66.9,82.9,76.4,59.2,77.3,66.2,86.6,64.2,73.2
                  
                 ],[17,9.7,9.9,9,6.8,11.6,8.7,9.7,9.9,10.7,8.8,11.9,
                  13.9, 4.2, 24.8, 12.6,11.5,9.7,10.3,10.9,9.2,10.9,10.2,8.4,7.4,11.6,10.9,9.5,8.1,5.8,12.4,10,6.7,9.1,
                   
                   
                
                 5.9,2.7,1.6,2.6,13.4,9.6,10,
                   
                   
                   
                   
                 7.6,14.8,10.7,3,4.1,5.2,4,5.3,13.9,6.8,14.5,5.1,18.9,17,4.7],
                 cmap="Blues", shade=True, shade_lowest=False)
#ax = sns.kdeplot(df["% of county Hispanic"],df["Increase in Unemployment Rate (Jan to April)"],
#                 cmap="Greens", shade=True, shade_lowest=False)

# %%
sns.set(style="darkgrid")



# Set up the figure first
f, ax = plt.subplots(figsize=(20, 12))
ax.set_aspect("equal")

scaled_data = scaler.fit_transform(W)
scaled_data2 = scaler.fit_transform(B)
scaled_data3 = scaler.fit_transform(A)

# Draw the two density plots

ax = sns.kdeplot([11.3,2.4,8.8,2.3,5,2.7,5.5,6.39,8.91,8.27,3.33,2.34,3.36,2.67,6.24,9.9,8.58,5.04,5.36,6.98,
                  2.46,2.02,2.55,14.3,2.73,2.46,3.06,
                  
                  
                  3.96,1.97,5.2,3.52,4.58,2.08,
                  
                  2.36,11.04,1.2,2.85,2.93,4.81,2.3,4.24
                 
                 ],[10.9,9.7,11.3,6.8,8.8,10.1,10.1,7.6,6,16.3,8.6,8.8,8.9,10.8,11.4,10.6,9.7,11.7,10.3,11.1,9.3,9.2,
                    9.1,11.1,10.9,6.7,9.1, 
                    
                    5.3,2.7,8.5,8.3,7.1,10,
                   
                   7.6,30.1,10.7,5.3,14.5,5.1,17,4.7
                   ],
                 cmap="Reds", shade=True, shade_lowest=False)
ax = sns.kdeplot([67.9,79.6,73.4,82.3,78.7,75.4,64,72.3,66.1,71.9,81.5,66.4,77.6,65.9,53.7,85.6,74.3,83.7,33.9,
                  33.2,58.2,81,85.9,77.6,64.4,69.8,83,81.2,57,
                 
                 
                 63.2,58.9,56.9,78.3,57.9,80.7,
                  
 
                 
                 74.5,81.5,84.8,98.3,76.4,86.6 
                  
                 ],[17,9.7,9.9,9,11.6,9.7,9.9,10.7,6,8.8,11.9,13.9,4.2,24.8,12.6,11.5,9.7,10.3,11.1,9.1,10.9,10.2,8.4,
                 7.4,11.6,8.1,5.8,12.4,9.1,
                   
                   
                
                 5.9,2.6,8.5,13.4,7.1,9.6,
                 
                    
                 7.6,14.8,3,4.1,13.9,18.9
                   ],
                   
                   
                   
    
                 cmap="Blues", shade=True, shade_lowest=False)
#ax = sns.kdeplot(df["% of county Hispanic"],df["Increase in Unemployment Rate (Jan to April)"],
#                 cmap="Greens", shade=True, shade_lowest=False)

# %%
from sklearn.cluster import KMeans
ax = sns.kdeplot([11.3,2.4,8.8,2.3,5,2.7,5.5,6.39,8.91,8.27,3.33,2.34,3.36,2.67,6.24,9.9,8.58,5.04,5.36,6.98,
                  2.46,2.02,2.55,14.3,2.73,2.46,3.06,
                  
                  
                  3.96,1.97,5.2,3.52,4.58,2.08,
                  
                  2.36,11.04,1.2,2.85,2.93,4.81,2.3,4.24
                 
                 ],[67.9,79.6,73.4,82.3,78.7,75.4,64,72.3,66.1,71.9,81.5,66.4,77.6,65.9,53.7,85.6,74.3,83.7,33.9,
                  33.2,58.2,81,85.9,77.6,64.4,69.8,83,81.2,57,
                 
                 
                 63.2,58.9,56.9,78.3,57.9,80.7,
                  
 
                 
                 74.5,81.5,84.8,98.3,76.4,86.6 
                  
                 ],
                 cmap="Reds", shade=True, shade_lowest=False)
"""
ax = sns.kdeplot([67.9,79.6,73.4,82.3,78.7,75.4,64,72.3,66.1,71.9,81.5,66.4,77.6,65.9,53.7,85.6,74.3,83.7,33.9,
                  33.2,58.2,81,85.9,77.6,64.4,69.8,83,81.2,57,
                 
                 
                 63.2,58.9,56.9,78.3,57.9,80.7,
                  
 
                 
                 74.5,81.5,84.8,98.3,76.4,86.6 
                  
                 ],[17,9.7,9.9,9,11.6,9.7,9.9,10.7,6,8.8,11.9,13.9,4.2,24.8,12.6,11.5,9.7,10.3,11.1,9.1,10.9,10.2,8.4,
                 7.4,11.6,8.1,5.8,12.4,9.1,
                   
                   
                
                 5.9,2.6,8.5,13.4,7.1,9.6,
                 
                    
                 7.6,14.8,3,4.1,13.9,18.9
                   ],
"""
# Out:
# '\nax = sns.kdeplot([67.9,79.6,73.4,82.3,78.7,75.4,64,72.3,66.1,71.9,81.5,66.4,77.6,65.9,53.7,85.6,74.3,83.7,33.9,\n                  33.2,58.2,81,85.9,77.6,64.4,69.8,83,81.2,57,\n                 \n                 \n                 63.2,58.9,56.9,78.3,57.9,80.7,\n                  \n \n                 \n                 74.5,81.5,84.8,98.3,76.4,86.6 \n                  \n                 ],[17,9.7,9.9,9,11.6,9.7,9.9,10.7,6,8.8,11.9,13.9,4.2,24.8,12.6,11.5,9.7,10.3,11.1,9.1,10.9,10.2,8.4,\n                 7.4,11.6,8.1,5.8,12.4,9.1,\n                   \n                   \n                \n                 5.9,2.6,8.5,13.4,7.1,9.6,\n                 \n                    \n                 7.6,14.8,3,4.1,13.9,18.9\n                   ],\n'

# %%
df2=pd.read_csv("Total Minority California Dataset - Sheet1.csv")
df2=df2.drop(["Population"],axis=1)
df2=df2.drop(["Counties"],axis=1)
df2.head()
X=df2.values

df3=pd.read_csv("Total Minority California Dataset - Sheet1.csv")
df3=df3.drop(["Population"],axis=1)
df3=df3.drop(["Counties"],axis=1)
df3=df3.drop(["% Total Minority"],axis=1)
df3.head()
Y=df3.values

# %%
df3.head()
# Out:
#    Increase in Unemployment Rate (Jan to April)  % of county White  \
# 0                                          10.9               32.6
# 1                                          17.0               67.9
# 2                                           9.7               79.6
# 3                                           9.9               73.4
# 4                                           9.0               82.3
#
#    % of county Black  % of county Asian  % of county Hispanic
# 0               11.3               28.2                  22.0
# 1                0.8                0.8                   7.8
# 2                2.4                1.5                  12.9
# 3                1.5                4.3                  15.3
# 4                0.6                1.0                  11.2

# %%
print(__doc__)


# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn import datasets

np.random.seed(5)

iris = datasets.load_iris()
y = iris.target

estimators = [
              ('k_means_iris_3', KMeans(n_clusters=3)),
              ]

fignum = 1
titles = ['3 clusters']
for name, est in estimators:
    fig = plt.figure(fignum, figsize=(4, 3))
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=45)
    est.fit(X)
    labels = est.labels_

    ax.scatter(X[:, 1], X[:, 2], X[:, 0],
               c=labels.astype(np.float), edgecolor='k')

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel('White %')
    ax.set_zlabel('Increase in Unemployment')
    ax.set_ylabel('Minority %')
    ax.set_title(titles[fignum - 1])
    ax.dist = 12
    fignum = fignum + 1

    print(est.cluster_centers_)

"""
    # Plot the ground truth
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)


for name, label in [('Setosa', 0),
                    ('Versicolour', 1),
                    ('Virginica', 2)]:
    ax.text3D(X[y == label, 3].mean(),
              X[y == label, 0].mean(),
              X[y == label, 2].mean() + 2, name,
              horizontalalignment='center',
              bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 3], X[:, 0], X[:, 2], c=y, edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('Petal width')
ax.set_ylabel('Sepal length')
ax.set_zlabel('Petal length')
ax.set_title('Ground Truth')
ax.dist = 12
"""

fig.show()
# Out:
#     # Plot the ground truth
# fig = plt.figure(fignum, figsize=(4, 3))
# ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
#
#
# for name, label in [('Setosa', 0),
#                     ('Versicolour', 1),
#                     ('Virginica', 2)]:
#     ax.text3D(X[y == label, 3].mean(),
#               X[y == label, 0].mean(),
#               X[y == label, 2].mean() + 2, name,
#               horizontalalignment='center',
#               bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))
# # Reorder the labels to have colors matching the cluster results
# y = np.choose(y, [1, 2, 0]).astype(np.float)
# ax.scatter(X[:, 3], X[:, 0], X[:, 2], c=y, edgecolor='k')
#
# ax.w_xaxis.set_ticklabels([])
# ax.w_yaxis.set_ticklabels([])
# ax.w_zaxis.set_ticklabels([])
# ax.set_xlabel('Petal width')
# ax.set_ylabel('Sepal length')
# ax.set_zlabel('Petal length')
# ax.set_title('Ground Truth')
# ax.dist = 12
#
# [[10.20526316 45.05789474  4.52526316 14.91578947 30.91578947 50.35684211]
# ...

# %%
print(__doc__)


# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn import datasets

np.random.seed(5)

iris = datasets.load_iris()
y = iris.target

estimators = [
              ('k_means_iris_3', KMeans(n_clusters=4)),
              ]

fignum = 1
titles = ['4 clusters']
for name, est in estimators:
    fig = plt.figure(fignum, figsize=(4, 3))
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=45)
    est.fit(Y)
    labels = est.labels_

    ax.scatter(X[:, 1], X[:, 5], X[:, 0],
               c=labels.astype(np.float), edgecolor='k')

    ax.w_xaxis.set_ticklabels([])
    ax.w_yaxis.set_ticklabels([])
    ax.w_zaxis.set_ticklabels([])
    ax.set_xlabel('White %')
    ax.set_zlabel('Increase in Unemployment')
    ax.set_ylabel('Minority %')
    ax.set_title(titles[fignum - 1])
    ax.dist = 12
    fignum = fignum + 1

    print(est.cluster_centers_)

"""
    # Plot the ground truth
fig = plt.figure(fignum, figsize=(4, 3))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)


for name, label in [('Setosa', 0),
                    ('Versicolour', 1),
                    ('Virginica', 2)]:
    ax.text3D(X[y == label, 3].mean(),
              X[y == label, 0].mean(),
              X[y == label, 2].mean() + 2, name,
              horizontalalignment='center',
              bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(np.float)
ax.scatter(X[:, 3], X[:, 0], X[:, 2], c=y, edgecolor='k')

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_xlabel('Petal width')
ax.set_ylabel('Sepal length')
ax.set_zlabel('Petal length')
ax.set_title('Ground Truth')
ax.dist = 12
"""

fig.show()
# Out:
#     # Plot the ground truth
# fig = plt.figure(fignum, figsize=(4, 3))
# ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
#
#
# for name, label in [('Setosa', 0),
#                     ('Versicolour', 1),
#                     ('Virginica', 2)]:
#     ax.text3D(X[y == label, 3].mean(),
#               X[y == label, 0].mean(),
#               X[y == label, 2].mean() + 2, name,
#               horizontalalignment='center',
#               bbox=dict(alpha=.2, edgecolor='w', facecolor='w'))
# # Reorder the labels to have colors matching the cluster results
# y = np.choose(y, [1, 2, 0]).astype(np.float)
# ax.scatter(X[:, 3], X[:, 0], X[:, 2], c=y, edgecolor='k')
#
# ax.w_xaxis.set_ticklabels([])
# ax.w_yaxis.set_ticklabels([])
# ax.w_zaxis.set_ticklabels([])
# ax.set_xlabel('Petal width')
# ax.set_ylabel('Sepal length')
# ax.set_zlabel('Petal length')
# ax.set_title('Ground Truth')
# ax.dist = 12
#
# [[10.075      33.925       3.86875     5.4875     53.80625   ]
# ...

# %%
dist=((10.075-11.1083)**2+(33.925-62.62)**2+(3.86-2.04)**2+(5.49-3.24)**2+(53.81-26.18)**2)**(1/2)
print(dist)
# Out:
# 39.953254359188314

# %%
sns.heatmap([[10.075,33.925,3.86875,5.4875,53.80625],
 [11.10833333,62.61666667,2.035,3.24166667,26.18333333],
 [10.20833333,41.45833333,6.06166667,20.33333333,27.08333333],
 [ 9.9,78.49444444,1.22166667,2.26666667,11.63333333]])

# %%
#sns.heatmap([[10.075,11.11,10.21,9.9],[33.93,62.61,41.46,78.49]])

plt.scatter([33.93,62.61,41.46,78.49],[10.075,11.11,10.21,9.9],)
plt.scatter([3.86875,2.035,6.06166667,1.22166667],[10.075,11.11,10.21,9.9])

# %%
from sklearn.preprocessing import StandardScaler
data=[[10.075,33.925,3.86875,5.4875,53.80625],
 [11.10833333,62.61666667,2.035,3.24166667,26.18333333],
 [10.20833333,41.45833333,6.06166667,20.33333333,27.08333333],
 [ 9.9,78.49444444,1.22166667,2.26666667,11.63333333]]
scaler=StandardScaler()
scaler.fit(data)
mean=scaler.mean_
mean=mean.tolist()

# %%
diff=[]
for i in range(4):
    list1=[]
    for j in range(5):
        temp=data[i][j]-mean[j]
        list1.append(temp)
    diff.append(list1)
print(diff)
# Out:
# [[-0.24791666499999998, -20.19861111, 0.5719791650000001, -2.3447916675, 24.129687502499998], [0.7854166650000014, 8.493055560000002, -1.2617708349999996, -4.5906249975, -3.493229167500001], [-0.11458333499999895, -12.665277779999997, 2.7648958350000004, 12.501041662499999, -2.5932291675000023], [-0.4229166649999989, 24.370833329999996, -2.075104165, -5.5656249975, -18.0432291675]]
