# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('genderovertime.csv', index_col = 'month')

men = data['Men, 20 years and over']
women = data['Women, 20 years and over']

# %%
y = men
print(len(men))
# Out:
# 26

# %%
x = range(0,26)
print(len(x))
mymodel = numpy.poly1d(numpy.polyfit(x, y, 7))
myline = numpy.linspace(1, 26, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()
# Out:
# 26
