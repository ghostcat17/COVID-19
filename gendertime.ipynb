# %%
import numpy
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv('genderovertime.csv', index_col = 'month')

men = data['Black or African American']
women = data['White']

# %%
y = men
print(len(men))
# Out:
# 26

# %%
x = range(0,26)
print(len(x))
mymodel = numpy.poly1d(numpy.polyfit(x, y, 10))
myline = numpy.linspace(1, 26, 100)
y2 = women
plt.scatter(x, y)
plt.scatter(x,y2)
mymodel2 = numpy.poly1d(numpy.polyfit(x, y2, 10))
myline2 = numpy.linspace(1, 26, 100)
mymodel = numpy.poly1d(numpy.polyfit(x, y, 10))
myline = numpy.linspace(1, 26, 100)

plt.plot(myline, mymodel(myline))
plt.plot(myline2, mymodel2(myline2))

plt.show()
# Out:
# 26
