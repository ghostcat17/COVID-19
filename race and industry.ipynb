# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
headers=['White','Black','Asian', 'Hispanic']

# %%
df = pd.read_csv('race and ethnicity.csv', names=headers)

# %%
plotdata = pd.DataFrame({
    "Management, professional, and related occupations":[-3.8,-4.4,-6.6,-5.4],
    "Service occupations":[2.4,3.7,5.1,3.5],
    "Sales and office occupations":[0.9,1.7,0.7,0.9],
    "Natural resources, construction, and maintenance occupations":[0.4,-0.4,-0.2,2.1],
    "Production, transportation, and material moving occupations":[0.1,-0.6,0.9,-1.1]
    }, 
    index=["White", "Black", "Asian", "Hispanic"]
)

# %%
plotdata.plot(kind="bar")
plt.title("Race and Industry")
plt.xlabel("Race")
plt.ylabel("Difference in unemployement rate")
leg = plt.legend( loc = 'upper left')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-f58ce16667dd> in <module>
#       1 fig, ax = plt.subplots(figsize=(20, 10))
# ----> 2 plotdata.plot(kind="bar")
#       3 plt.title("Race and Industry")
#       4 plt.xlabel("Race")
#       5 plt.ylabel("Difference in unemployement rate")
#
# AttributeError: 'tuple' object has no attribute 'plot'

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-940e99d3a124> in <module>
# ----> 1 plt.bar(r1, df['White'].values, width=barWidth, label='White')
#       2 plt.bar(r2, df['Black'].values, width=barWidth, label='Black')
#       3 plt.bar(r3, df['Asian'].values,  width=barWidth,  label='Asian')
#       4 plt.bar(r4, df['Hispanic'].values,  width=barWidth,label='Hispanic')
#       5
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2432     return gca().bar(
#    2433         x, height, width=width, bottom=bottom, align=align,
# -> 2434         **({"data": data} if data is not None else {}), **kwargs)
#    2435
#    2436
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
# ...
