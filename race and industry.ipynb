# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_csv('race and industry.csv')

# %%
print(df)
# Out:
#    Occupation, race, and Hispanic or Latino ethnicity       Total  Unnamed: 2  \
# 0                                                 NaN  June\n2019  June\n2020
# 1                                               TOTAL         NaN         NaN
# 2                Total, 16 years and over (thousands)     157,828     142,811
# 3                           Percent of total employed         100         100
# 4   Management, professional, and related occupations        40.2        44.3
# 5   Management, business, and financial operations...          17        18.8
# 6                Professional and related occupations        23.2        25.5
# 7                                 Service occupations        17.7        14.8
# 8                        Sales and office occupations        20.9          20
# 9                       Sales and related occupations         9.8         9.4
# 10      Office and administrative support occupations        11.2        10.5
# 11  Natural resources, construction, and maintenan...         9.1         8.9
# 12         Farming, fishing, and forestry occupations         0.7         0.7
# 13            Construction and extraction occupations         5.3         5.2
# 14  Installation, maintenance, and repair occupations         3.1         3.1
# 15  Production, transportation, and material movin...          12          12
# 16                             Production occupations         5.6           5
# 17     Transportation and material moving occupations         6.5         6.9
# 18                                                NaN         NaN         NaN
# 19                                              White         NaN         NaN
# 20               Total, 16 years and over (thousands)     122,708     112,020
# 21                          Percent of total employed         100         100
# 22  Management, professional, and related occupations        40.7        44.5
# 23  Management, business, and financial operations...        17.9        19.8
# 24               Professional and related occupations        22.8        24.7
# 25                                Service occupations        16.7        14.3
# 26                       Sales and office occupations          21        20.1
# 27                      Sales and related occupations         9.9         9.6
# 28      Office and administrative support occupations        11.1        10.5
# 29  Natural resources, construction, and maintenan...        10.2         9.8
# ..                                                ...         ...         ...
# 61               Professional and related occupations        36.5        43.9
# 62                                Service occupations        15.7        10.6
# 63                       Sales and office occupations          16        15.3
# 64                      Sales and related occupations         8.2         7.3
# 65      Office and administrative support occupations         7.8         7.9
# 66  Natural resources, construction, and maintenan...         2.8           3
# 67         Farming, fishing, and forestry occupations         0.1         0.1
# 68            Construction and extraction occupations         1.4         1.1
# 69  Installation, maintenance, and repair occupations         1.4         1.8
# 70  Production, transportation, and material movin...         9.2         8.3
# 71                             Production occupations         5.4         3.9
# 72     Transportation and material moving occupations         3.8         4.3
# 73                                                NaN         NaN         NaN
# 74                       Hispanic or Latino ethnicity         NaN         NaN
# 75               Total, 16 years and over (thousands)      27,721      24,794
# 76                          Percent of total employed         100         100
# 77  Management, professional, and related occupations          23        28.4
# 78  Management, business, and financial operations...        10.3        13.2
# 79               Professional and related occupations        12.7        15.3
# 80                                Service occupations        24.4        20.9
# 81                       Sales and office occupations        20.4        19.5
# 82                      Sales and related occupations         9.3         9.5
# 83      Office and administrative support occupations          11        10.1
# 84  Natural resources, construction, and maintenan...        16.8        14.7
# 85         Farming, fishing, and forestry occupations         1.9         1.5
# 86            Construction and extraction occupations          11          10
# 87  Installation, maintenance, and repair occupations         3.8         3.2
# 88  Production, transportation, and material movin...        15.4        16.5
# 89                             Production occupations         7.2         6.9
# 90     Transportation and material moving occupations         8.2         9.6
#
#            Men  Unnamed: 4       Women  Unnamed: 6  Unnamed: 7  \
# 0   June\n2019  June\n2020  June\n2019  June\n2020         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2       84,189      76,425      73,639      66,386         NaN
# 3          100         100         100         100         NaN
# 4         36.7        40.2        44.2          49         NaN
# 5         18.1        19.7        15.8        17.9         NaN
# 6         18.6        20.6        28.4        31.1         NaN
# 7         14.2        12.2        21.7        17.8         NaN
# 8         15.5        14.5        27.1        26.2         NaN
# 9          9.4         9.1        10.2         9.8         NaN
# 10         6.1         5.4        16.9        16.4         NaN
# 11        16.3        15.8           1         1.1         NaN
# 12           1           1         0.4         0.3         NaN
# 13         9.6         9.2         0.4         0.5         NaN
# 14         5.6         5.6         0.2         0.3         NaN
# 15        17.3        17.2           6         5.9         NaN
# 16         7.3         6.9         3.6         2.9         NaN
# 17          10        10.3         2.5           3         NaN
# 18         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN
# 20      66,796      61,181      55,912      50,838         NaN
# 21         100         100         100         100         NaN
# 22        36.9        40.4        45.2        49.5         NaN
# 23        19.1        20.9        16.3        18.5         NaN
# 24        17.7        19.5        28.9          31         NaN
# 25        13.5        11.9        20.6        17.2         NaN
# 26        15.4        14.4        27.7        26.9         NaN
# 27         9.6         9.4        10.2         9.8         NaN
# 28         5.8           5        17.4          17         NaN
# 29        17.8          17         1.1         1.2         NaN
# ..         ...         ...         ...         ...         ...
# 61          39        45.4        33.7        42.3         NaN
# 62        12.3         7.8        19.5        13.7         NaN
# 63        12.6        12.9        19.7          18         NaN
# 64         7.8         7.7         8.6           7         NaN
# 65         4.8         5.2        11.1          11         NaN
# 66         5.1           5         0.3         0.7         NaN
# 67           0         0.1         0.1         0.1         NaN
# 68         2.5         1.8         0.1         0.2         NaN
# 69         2.5         3.1         0.1         0.4         NaN
# 70        11.4        10.1         6.8         6.1         NaN
# 71         5.4           4         5.4         3.9         NaN
# 72         5.9         6.1         1.4         2.2         NaN
# 73         NaN         NaN         NaN         NaN         NaN
# 74         NaN         NaN         NaN         NaN         NaN
# 75      15,835      14,139      11,886      10,656         NaN
# 76         100         100         100         100         NaN
# 77        19.4        24.2        27.7          34         NaN
# 78        10.4        12.5        10.3        14.1         NaN
# 79         9.1        11.8        17.4        19.9         NaN
# 80        18.7          17        32.1        25.9         NaN
# 81        14.8        13.8        27.7        27.2         NaN
# 82         8.2         8.3        10.8          11         NaN
# 83         6.6         5.5        16.9        16.1         NaN
# 84        27.6        24.2         2.3           2         NaN
# 85         2.4           2         1.2         0.9         NaN
# 86        18.8        16.9         0.8         0.7         NaN
# 87         6.4         5.3         0.4         0.4         NaN
# 88        19.5        20.7        10.1        10.9         NaN
# 89         7.9         8.2         6.3         5.3         NaN
# 90        11.6        12.5         3.8         5.6         NaN
#
#                                            Unnamed: 8          Unnamed: 9  \
# 0                                                 NaN                 NaN
# 1                                                 NaN                 NaN
# 2                                                 NaN                 NaN
# 3                                                 NaN                 NaN
# 4                                                 NaN                 NaN
# 5                                                 NaN                 NaN
# 6                                                 NaN                 NaN
# 7                                                 NaN                 NaN
# 8                                                 NaN     White pre-COVID
# 9   Management, professional, and related occupations                40.7
# 10                                Service occupations                16.7
# 11                       Sales and office occupations                  21
# 12  Natural resources, construction, and maintenan...                10.2
# 13  Production, transportation, and material movin...                11.4
# 14                                                NaN                 NaN
# 15                                                NaN  White during COVID
# 16  Management, professional, and related occupations                44.5
# 17                                Service occupations                14.3
# 18                       Sales and office occupations                20.1
# 19  Natural resources, construction, and maintenan...                 9.8
# 20  Production, transportation, and material movin...                11.3
# 21                                                NaN              White
# 22  Management, professional, and related occupations        -74.92884726
# 23                                Service occupations         47.32348248
# 24                       Sales and office occupations         17.74630593
# 25  Natural resources, construction, and maintenan...          7.88724708
# 26  Production, transportation, and material movin...          1.97181177
# 27                                                NaN                 NaN
# 28                                                NaN                 NaN
# 29                                              white         197,181,177
# ..                                                ...                 ...
# 61                                                NaN                 NaN
# 76  ...         NaN         NaN         NaN         NaN         NaN
# 77  ...         NaN         NaN         NaN         NaN         NaN
# 78  ...         NaN         NaN         NaN         NaN         NaN
# 79  ...         NaN         NaN         NaN         NaN         NaN
# 80  ...         NaN         NaN         NaN         NaN         NaN
# 81  ...         NaN         NaN         NaN         NaN         NaN
# 82  ...         NaN         NaN         NaN         NaN         NaN
# 83  ...         NaN         NaN         NaN         NaN         NaN
# 84  ...         NaN         NaN         NaN         NaN         NaN
# 85  ...         NaN         NaN         NaN         NaN         NaN
# 86  ...         NaN         NaN         NaN         NaN         NaN
# 87  ...         NaN         NaN         NaN         NaN         NaN
# 88  ...         NaN         NaN         NaN         NaN         NaN
# 89  ...         NaN         NaN         NaN         NaN         NaN
# 90  ...         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 25 Unnamed: 26 Unnamed: 27 Unnamed: 28 Unnamed: 29
# 0          NaN         NaN         NaN         NaN         NaN
# 1          NaN         NaN         NaN         NaN         NaN
# 2          NaN         NaN         NaN         NaN         NaN
# 3          NaN         NaN         NaN         NaN         NaN
# 4          NaN         NaN         NaN         NaN         NaN
# 5          NaN         NaN         NaN         NaN         NaN
# 6          NaN         NaN         NaN         NaN         NaN
# 7          NaN         NaN         NaN         NaN         NaN
# 8          NaN         NaN         NaN         NaN         NaN
# 9          NaN         NaN         NaN         NaN         NaN
# 10         NaN         NaN         NaN         NaN         NaN
# 11         NaN         NaN         NaN         NaN         NaN
# 12         NaN         NaN         NaN         NaN         NaN
# 13         NaN         NaN         NaN         NaN         NaN
# 14         NaN         NaN         NaN         NaN         NaN
# 15         NaN         NaN         NaN         NaN         NaN
# 16         NaN         NaN         NaN         NaN         NaN
# 17         NaN         NaN         NaN         NaN         NaN
# 18         NaN         NaN         NaN         NaN         NaN
# 19         NaN         NaN         NaN         NaN         NaN
# 20         NaN         NaN         NaN         NaN         NaN
# 21         NaN         NaN         NaN         NaN         NaN
# 22         NaN         NaN         NaN         NaN         NaN
# 23         NaN         NaN         NaN         NaN         NaN
# 24         NaN         NaN         NaN         NaN         NaN
# 25         NaN         NaN         NaN         NaN         NaN
# 26         NaN         NaN         NaN         NaN         NaN
# 27         NaN         NaN         NaN         NaN         NaN
# 28         NaN         NaN         NaN         NaN         NaN
# 29         NaN         NaN         NaN         NaN         NaN
# ..         ...         ...         ...         ...         ...
# 61         NaN         NaN         NaN         NaN         NaN
# 62         NaN         NaN         NaN         NaN         NaN
# 63         NaN         NaN         NaN         NaN         NaN
# 64         NaN         NaN         NaN         NaN         NaN
# 65         NaN         NaN         NaN         NaN         NaN
# 66         NaN         NaN         NaN         NaN         NaN
# 67         NaN         NaN         NaN         NaN         NaN
# 68         NaN         NaN         NaN         NaN         NaN
# 69         NaN         NaN         NaN         NaN         NaN
# 70         NaN         NaN         NaN         NaN         NaN
# 71         NaN         NaN         NaN         NaN         NaN
# 72         NaN         NaN         NaN         NaN         NaN
# 73         NaN         NaN         NaN         NaN         NaN
# 74         NaN         NaN         NaN         NaN         NaN
# 75         NaN         NaN         NaN         NaN         NaN
# 76         NaN         NaN         NaN         NaN         NaN
# 77         NaN         NaN         NaN         NaN         NaN
# 78         NaN         NaN         NaN         NaN         NaN
# 79         NaN         NaN         NaN         NaN         NaN
# 80         NaN         NaN         NaN         NaN         NaN
# 81         NaN         NaN         NaN         NaN         NaN
# 82         NaN         NaN         NaN         NaN         NaN
# 83         NaN         NaN         NaN         NaN         NaN
# 84         NaN         NaN         NaN         NaN         NaN
# 85         NaN         NaN         NaN         NaN         NaN
# 86         NaN         NaN         NaN         NaN         NaN
# 87         NaN         NaN         NaN         NaN         NaN
# 88         NaN         NaN         NaN         NaN         NaN
# 89         NaN         NaN         NaN         NaN         NaN
# 90         NaN         NaN         NaN         NaN         NaN
#
# [91 rows x 30 columns]

# %%
corr = df.corr()

# %%
mask = np.zeros_like(corr, dtype=np.bool)

# %%
mask[np.triu_indices_from(mask)] = True

# %%
# Set up the matplotlib figure

# %%
f, ax = plt.subplots(figsize=(11, 9))

# %%
sns.heatmap(corr)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-911aa23b3c54> in <module>
# ----> 1 sns.heatmap(corr)
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     515     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     516                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 517                           yticklabels, mask)
#     518
#     519     # Add the pcolormesh kwargs here
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     165         # Determine good default values for the colormapping
#     166         self._determine_cmap_params(plot_data, vmin, vmax,
# --> 167                                     cmap, center, robust)
#     168
#     169         # Sort out the annotations
#
# ~\Anaconda3\lib\site-packages\seaborn\matrix.py in _determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     204         calc_data = plot_data.data[~np.isnan(plot_data.data)]
#     205         if vmin is None:
# --> 206             vmin = np.percentile(calc_data, 2) if robust else calc_data.min()
#     207         if vmax is None:
#     208             vmax = np.percentile(calc_data, 98) if robust else calc_data.max()
#
# ~\Anaconda3\lib\site-packages\numpy\core\_methods.py in _amin(a, axis, out, keepdims, initial)
#      30 def _amin(a, axis=None, out=None, keepdims=False,
#      31           initial=_NoValue):
# ---> 32     return umr_minimum(a, axis, None, out, keepdims, initial)
#      33
#      34 def _sum(a, axis=None, dtype=None, out=None, keepdims=False,
#
# ValueError: zero-size array to reduction operation minimum which has no identity
