# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

data = pd.read_csv("stateovertime.csv", index_col = 'State')

# %%
state_dict = {}

for state in data.columns:
    state_dict[state] = data[state]

#print(state_dict["Illinois"])

# %%
fig, a = plt.subplots(5, 10)
row = 0
column = 0

for state in state_dict.keys():    
    
    x = range(len(state_dict[state]))
    temp = state_dict[state]
    
    #plt.scatter(x, temp)
    my_model = np.poly1d(np.polyfit(x, temp,10))
    my_line = np.linspace(1, x, 100)
    a[row][column].plot(my_line, my_model(my_line))
    a[row][column].scatter(x, temp)
    a[row][column].set_title(state)
    
    column += 1    
    if (column == 10 and row < 5):
        row += 1
        column = 0
        
    
    fig = plt.gcf()
    fig.set_size_inches(20,12)
    fig.subplots_adjust(hspace=0.50)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-ee9e8f6c65bb> in <module>
#      11     my_model = np.poly1d(np.polyfit(x, temp,10))
#      12     my_line = np.linspace(1, x, 100)
# ---> 13     a[row][column].plot(my_line, my_model(my_line))
#      14     a[row][column].scatter(x, temp)
#      15     a[row][column].set_title(state)
#
# IndexError: index 5 is out of bounds for axis 0 with size 5

# %%
'''x = range(len(state_dict["Alabama"]))

plt.scatter(x, state_dict['Alabama'])

my_model = np.poly1d(np.polyfit(x, state_dict['Alabama'], 10))
my_line = np.linspace(1, x, 100)

plt.plot(my_line, my_model(my_line))

plt.show()'''
