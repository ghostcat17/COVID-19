# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import ssl

# %%
data = pd.read_csv("cleancountydata.csv")

# %%
data.head()
# Out:
#     Counties  Population  Increase in Unemployment Rate (Jan to April)  \
# 0    Alameda     1666750                                          10.9
# 1     Alpine        1101                                          17.0
# 2     Amador       39383                                           9.7
# 3      Butte      231256                                           9.9
# 4  Calaveras       45602                                           9.0
#
#    % of county White  % of county Black  % of county Asian  \
# 0               32.6               11.3               28.2
# 1               67.9                0.8                0.8
# 2               79.6                2.4                1.5
# 3               73.4                1.5                4.3
# 4               82.3                0.6                1.0
#
#    % of county Hispanic
# 0                  22.0
# 1                   7.8
# 2                  12.9
# 3                  15.3
# 4                  11.2

# %%
data.shape
# Out:
# (58, 7)

# %%
stuff = pd.plotting.scatter_matrix(data[["Population", r"Increase in Unemployment Rate (Jan to April)", "% of county White", "% of county Black", "% of county Asian", "% of county Hispanic"]], figsize=(15,15), alpha=1)

# %%
sns.pairplot(data, x_vars=["Population", r"Increase in Unemployment Rate (Jan to April)", "% of county White", "% of county Black", "% of county Asian", "% of county Hispanic"], y_vars=["Population", r"Increase in Unemployment Rate (Jan to April)", "% of county White", "% of county Black", "% of county Asian", "% of county Hispanic"], kind='reg')

# %%
sns.heatmap(data.corr())

# %%
sns.heatmap(data.corr().abs())
