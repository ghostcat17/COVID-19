# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import numpy as np

# %%
df = pd.read_csv("cc-est2019-alldata.csv", encoding="cp1252")

# %%
"""
df=df.drop(df.columns[20:56], axis=1)
df=df.drop(df.columns[22:],axis=1)
df = df[df.YEAR == 12]
df=df[df.AGEGRP == 0]
df=df.drop(["IA_MALE"],axis=1)
df=df.drop(["IA_FEMALE"],axis=1)
df=df.drop(["NA_MALE"],axis=1)
df=df.drop(["NA_FEMALE"],axis=1)
"""

df=df.drop(df.columns[20:34], axis=1)
df=df.drop(df.columns[22:42],axis=1)
df=df.drop(df.columns[24:],axis=1)
df = df[df.YEAR == 12]
df=df[df.AGEGRP == 0]
df=df[df.STNAME!="Alaska"]
df=df[df.STNAME!="Hawaii"]
df=df.drop(["NA_MALE"],axis=1)
df=df.drop(["NA_FEMALE"],axis=1)
df=df.drop(["WA_MALE"],axis=1)
df=df.drop(["WA_FEMALE"],axis=1)

# %%
df2=pd.read_csv("Unemployment_Change.csv")

# %%
W=[]
M=[]
U=[]
for i in range(3108):
    total_pop=df.iloc[i,7]
    white_pop=df.iloc[i,16]+df.iloc[i,17]
    white_percent=((white_pop)/(total_pop))*100
    W.append(white_percent)
    
    minority_pop=df.iloc[i,10]+df.iloc[i,11]+df.iloc[i,12]+df.iloc[i,13]+df.iloc[i,14]+df.iloc[i,15]+df.iloc[i,18]+df.iloc[i,19]
    minority_percent=((minority_pop)/(total_pop))*100
    M.append(minority_percent)

for i in range(3108):
    U.append(df2.iloc[i,1])

df["% White"]=W
df["% Minority"]=M
df["Unemployment Change"]=U

# %%
X=df.values

# %%
df.head()
# Out:
#       SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 209       50      1       1  Alabama  Autauga County    12       0    55869
# 437       50      1       3  Alabama  Baldwin County    12       0   223234
# 665       50      1       5  Alabama  Barbour County    12       0    24686
# 893       50      1       7  Alabama     Bibb County    12       0    22394
# 1121      50      1       9  Alabama   Blount County    12       0    57826
#
#       TOT_MALE  TOT_FEMALE  ...  AA_MALE  AA_FEMALE  NHWA_MALE  NHWA_FEMALE  \
# 209      27092       28777  ...      286        370      20138        21077
# 437     108247      114987  ...      932       1448      89845        95902
# 665      13064       11622  ...       55         61       5894         5341
# 893      11929       10465  ...       23         25       8482         8181
# 1121     28472       29354  ...       85        100      24494        25682
#
#       H_MALE  H_FEMALE    % White  % Minority  Unemployment Change  \
# 209      884       787  73.770785   24.754336                  9.1
# 437     5545      4989  83.207307   15.342197                 12.9
# 665      629       488  45.511626   53.913149                  6.6
# 893      343       280  74.408324   24.725373                 14.8
# 1121    2950      2632  86.770657   12.304154                  7.1
#
#       % UR Increase
# 209         395.652
# 437         516.000
# 665         200.000
# 893         510.345
# 1121        308.696
#
# [5 rows x 24 columns]

# %%
df3=df
df3.head()
# Out:
#       SUMLEV  STATE  COUNTY   STNAME         CTYNAME  YEAR  AGEGRP  TOT_POP  \
# 209       50      1       1  Alabama  Autauga County    12       0    55869
# 437       50      1       3  Alabama  Baldwin County    12       0   223234
# 665       50      1       5  Alabama  Barbour County    12       0    24686
# 893       50      1       7  Alabama     Bibb County    12       0    22394
# 1121      50      1       9  Alabama   Blount County    12       0    57826
#
#       TOT_MALE  TOT_FEMALE  ...  IA_FEMALE  AA_MALE  AA_FEMALE  NHWA_MALE  \
# 209      27092       28777  ...        145      286        370      20138
# 437     108247      114987  ...        839      932       1448      89845
# 665      13064       11622  ...         67       55         61       5894
# 893      11929       10465  ...         50       23         25       8482
# 1121     28472       29354  ...        178       85        100      24494
#
#       NHWA_FEMALE  H_MALE  H_FEMALE    % White  % Minority  \
# 209         21077     884       787  73.770785   24.754336
# 437         95902    5545      4989  83.207307   15.342197
# 665          5341     629       488  45.511626   53.913149
# 893          8181     343       280  74.408324   24.725373
# 1121        25682    2950      2632  86.770657   12.304154
#
#       Unemployment Change
# 209                   9.1
# 437                  12.9
# 665                   6.6
# 893                  14.8
# 1121                  7.1
#
# [5 rows x 23 columns]

# %%
for i in range(20):
    df3=df3.drop(df.columns[i],axis=1)
df3.head()
Y=df3.values

# %%
print(__doc__)


# Code source: Gaël Varoquaux
# Modified for documentation by Jaques Grobler
# License: BSD 3 clause

import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import KMeans
from sklearn import datasets

estimators = [
              ('k_means_iris_3', KMeans(n_clusters=3)),
              ]

fignum = 1
titles = ['3 clusters']
for name, est in estimators:
    fig = plt.figure(fignum, figsize=(12, 8))
    ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=45)
    est.fit(Y)
    labels = est.labels_

    ax.scatter(X[:, 20], X[:, 21], X[:, 22]
                ,c=labels.astype(np.float), edgecolor='k')
    ax.scatter(0,0,0)
    ax.scatter(100,100,0)

    ax.set_xlabel('White %')
    ax.set_zlabel('Increase in Unemployment')
    ax.set_ylabel('Minority %')
    ax.set_title(titles[fignum - 1])
    ax.dist = 12
    fignum = fignum + 1

    print(est.cluster_centers_)

fig.show()
# Out:
# df=df.drop(df.columns[20:56], axis=1)
# df=df.drop(df.columns[22:],axis=1)
# df = df[df.YEAR == 12]
# df=df[df.AGEGRP == 0]
# df=df.drop(["IA_MALE"],axis=1)
# df=df.drop(["IA_FEMALE"],axis=1)
# df=df.drop(["NA_MALE"],axis=1)
# df=df.drop(["NA_FEMALE"],axis=1)
#
# [[89.53597468  9.16161114  9.18634904]
#  [34.91494463 65.49597163  8.13333333]
#  [64.95956898 34.04754446  8.27557604]]
# /anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:459: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "
